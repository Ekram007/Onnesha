# %%
import pandas as pd
import re
import string
from string import digits
import numpy as np
from sklearn.utils import shuffle
from keras.layers import Input, LSTM, Embedding, Dense,Dropout,TimeDistributed , Reshape, Concatenate
from keras.models import Model
import tensorflow as tf
import math
from keras.models import Sequential
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
import pandas as pd
import io
import csv
from google.colab import files

# %%
text = files.upload()
# Out:
#      <input type="file" id="files-ea81b9dd-d2f3-4580-ab32-8d5f624ff234" name="files[]" multiple disabled />
#      <output id="result-ea81b9dd-d2f3-4580-ab32-8d5f624ff234">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sadashidhekotha.txt to sadashidhekotha.txt

# %%
data_path = 'sadashidhekotha.txt'
with open(data_path, 'r', encoding='utf8') as file:
    text = file.read()

# %%
#text='ঠিক কী কারণ জানা নেই, কোনো ভয়ংকর খবর পড়লে নিজের অজান্তেই আমি নিজেকে সে অবস্থানে কল্পনা করতে শুরু করি। পদ্মা নদীতে লঞ্চডুবির খবর পড়লে আমি কল্পনায় দেখতে পাই একটা লঞ্চ ডুবে যাচ্ছে, আমি তার ভেতরে আটকা পড়েছি, পানি ঢুকছে, মানুষ আতংকে চিৎকার করছে আর পানির নিচে নিঃশ্বাস নিতে না পেরে আমি ছটফট করছি। যখন একটা বাসে পেট্রোল বোমা দিয়ে আগুন ধরিয়ে দেওয়ার খবর পড়ি, তখন কল্পনায় দেখতে পাই আমি বাসের ভেতর আটকা পড়েছি, দাউ দাউ করে আগুন জ্বলছে আর আমি তার ভেতর দিয়ে ছুটে বের হওয়ার চেষ্টা করছি; আমার সারা শরীরে আগুন জ্বলছে।পরশু দিন আমি যখন খবর পেয়েছি অভিজিৎকে বইমেলার সামনে কুপিয়ে হত্যা করেছে, তখন পুরো দৃশ্যটি আমি আবার দেখতে পেয়েছি– এই দৃশ্যটি আমার জন্যে অনেক বেশি জীবন্ত; কারণ অভিজিৎ যে রকম বই মেলা ঘুরে তার স্ত্রীকে নিয়ে হেঁটে হেঁটে বের হয়ে এসেছে, আমি আর আমার স্ত্রী গত সপ্তাহে ঠিক একইভাবে মেলা থেকে হেঁটে হেঁটে বের হয়ে এসেছি। আমি জানি, অভিজিতের মতো আমার নামও জঙ্গিদের তালিকায় আছে। কল্পনায় দেখেছি, আমার মাথায় আঘাতের পর আঘাত পড়ছে, আমার স্ত্রী আমাকে বাঁচাতে গিয়ে ছিন্নভিন্ন হয়ে যাচ্ছে। কাছে, খুব কাছেই পুলিশ নিস্পৃহভাবে দাঁড়িয়ে আছে, তাকিয়ে তাকিয়ে ঘটনাটা দেখছে, কিন্তু কিছু করছে না। সিলেটে বসে আমি প্রায় সাথে সাথেই ঘটনাটা জানতে পেরেছিলাম। অভিজিৎকে হাসপাতালে নিয়েছে জেনে দোয়া করছিলাম যেন বেঁচে যায়, কিন্তু অভিজিৎ বাঁচল না। অভিজিৎ রায় আমার ঢাকা বিশ্ববিদ্যালয়ের শিক্ষক প্রফেসর অজয় রায়ের ছেলে। যারা হাসপাতালে ছিল তাদের কাছে আমাদের স্যারের খবর নিয়েছি। একজন বাবার কাছে তাঁর সন্তানের মৃত্যুসংবাদ থেকে কঠিন সংবাদ আর কী হতে পারে? আমাদের পদার্থ বিজ্ঞানের স্যার প্রফেসর অজয় রায় এই ভয়ংকর দুঃসময়ে তাঁর বুকের ভেতরের ওথাল পাথাল হাহাকার ঢেকে রেখে যে অসাধারণ মানসিক শক্তিতে বলীয়ান হয়ে সন্তানের মৃত্যুসংবাদ গ্রহণ করেছেন, প্রিয়জনের সাথে কথা বলেছেন, গণমাধ্যমের মুখোমুখি হয়েছেন, তার কোনো তুলনা নেই। আমরা তাঁর ছাত্রছাত্রীরা যদি তাঁর ভেতরকার শক্তির একটা ক্ষুদ্র অংশও আমাদের জীবনের কোথাও ব্যবহার করতে পারি তাহলে ধন্য মনে করব। আমি আসলে ফেসবুক, নেট, ব্লগের সাথে পরিচিত নই। আমি জানি সারা পৃথিবীতেই এটি খুব গুরুত্বপূর্ণ ভূমিকা রাখছে। তারপরও আমি শুধুমাত্র বইপত্র, ছাপা খবরের কাগজ দিয়েই দুনিয়ার খবর রাখি। সে কারণে আমি অভিজিত রায়ের ব্লগ জগতের সাথে পরিচিত ছিলাম না, আমি শুধুমাত্র তার বইয়ের সাথে পরিচিত ছিলাম। আমি আমার নিজের লেখায় তার বই থেকে উদ্ধৃতি দিয়েছি। আমার খুব আনন্দ হত যখন আমি দেখতাম একজন তরুণ ইঞ্জিনিয়ার কী সুন্দর ঝরঝরে বাংলায় লিখে, কী সুন্দর বিশ্লেষণ করে, কত খাটাখাটুনি করে একটা বিষয় যুক্তি-তর্ক দিয়ে বুঝিয়ে দিতে পারে। আমি জানতাম না ধর্মান্ধ গোষ্ঠী তাকে এভাবে টার্গেট করেছে। ধর্মান্ধ জঙ্গি গোষ্ঠীর তালিকায় আমাদের অনেকেরই নাম আছে, আমরা ধরেই নিয়েছি এই দেশে এভাবেই বেঁচে থাকতে হয়। কিন্তু সত্যি সত্যি যে তারা অভিজিৎকে এভাবে হত্যা করার একটা সুযোগ পেয়ে যাবে আমি কল্পনাও করতে পারিনি। স্বজন-হারানোর এই দুঃখ আমি কোথায় রাখি? শনিবার দুপুরে আমাদের বিশ্ববিদ্যালয়ের সাধারণ ছাত্রছাত্রীরা অভিজিৎ হত্যার প্রতিবাদে একটি মানববন্ধন ও মৌনমিছিল শেষে আমাদের লাইব্রেরির সামনে জমায়েত হয়েছিল। ছাত্র-শিক্ষকরা নিজেদের ক্ষোভের কথা বলেছেন, দুঃখের কথা বলেছেন, হতাশার কথা বলেছেন, অভিজিতের জন্যে গভীর শ্রদ্ধা আর ভালোবাসার কথা বলেছেন। সমাবেশের শেষে তারা আমার হাতেও মাইক্রোফোন দিয়ে তাদের জন্যে কিছু বলতে বলেছে।'

text = text.replace("?","।")
text = text.replace("!","।")
lines = text.split("।")
for i,val in enumerate(lines):
  lines[i] = val.replace('\n', '')
for i,val in enumerate(lines): 
  lines[i] = val.replace('“','')
for i,val in enumerate(lines): 
  lines[i] = val.replace('”','')
for i,val in enumerate(lines): 
  lines[i] = val.replace(',','')
for i,val in enumerate(lines): 
  lines[i] = val.replace('’','')
for i,val in enumerate(lines): 
  lines[i] = val.replace('‘','')
for i,val in enumerate(lines): 
  lines[i] = val.replace('(','')
for i,val in enumerate(lines): 
  lines[i] = val.replace(')','')
for i,val in enumerate(lines): 
  lines[i] = val.strip()
for i,val in enumerate(lines):
  lines[i] ='START_ '+ val + ' _END'

del lines[-1]
lines
# Out:
# ['START_ \ufeffপ্রিয় অভিজিৎঠিক কী কারণ জানা নেই কোনো ভয়ংকর খবর পড়লে নিজের অজান্তেই আমি নিজেকে সে অবস্থানে কল্পনা করতে শুরু করি _END',
#  'START_ পদ্মা নদীতে লঞ্চডুবির খবর পড়লে আমি কল্পনায় দেখতে পাই একটা লঞ্চ ডুবে যাচ্ছে আমি তার ভেতরে আটকা পড়েছি পানি ঢুকছে মানুষ আতংকে চিৎকার করছে আর পানির নিচে নিঃশ্বাস নিতে না পেরে আমি ছটফট করছি _END',
#  'START_ যখন একটা বাসে পেট্রোল বোমা দিয়ে আগুন ধরিয়ে দেওয়ার খবর পড়ি তখন কল্পনায় দেখতে পাই আমি বাসের ভেতর আটকা পড়েছি দাউ দাউ করে আগুন জ্বলছে আর আমি তার ভেতর দিয়ে ছুটে বের হওয়ার চেষ্টা করছি; আমার সারা শরীরে আগুন জ্বলছে _END',
#  'START_ পরশু দিন আমি যখন খবর পেয়েছি অভিজিৎকে বইমেলার সামনে কুপিয়ে হত্যা করেছে তখন পুরো দৃশ্যটি আমি আবার দেখতে পেয়েছি– এই দৃশ্যটি আমার জন্যে অনেক বেশি জীবন্ত; কারণ অভিজিৎ যে রকম বই মেলা ঘুরে তার স্ত্রীকে নিয়ে হেঁটে হেঁটে বের হয়ে এসেছে আমি আর আমার স্ত্রী গত সপ্তাহে ঠিক একইভাবে মেলা থেকে হেঁটে হেঁটে বের হয়ে এসেছি _END',
#  'START_ আমি জানি অভিজিতের মতো আমার নামও জঙ্গিদের তালিকায় আছে _END',
# ...

# %%
#Make the vocabulary
all_words=set()
for voc in lines:
    for word in voc.split():
          if word not in all_words:
            all_words.add(word)

all_words
# Out:
# {'হতাশাগ্রস্থ',
#  'কয়েকবার',
#  'বগিতে',
#  'বাংলাদেশপ্রায়',
#  'প্রশ্ন',
#  'পুনরাবৃত্তি',
#  'দেখ',
#  'উপদেশ',
#  'তিনশ',
#  'গেটটার',
#  'অপছন্দ',
#  'অবদান',
#  'ভোটেই',
#  'দলবল',
#  'লেখাটি',
#  'তাঁকে',
#  'ষেষ্টা',
#  'কাঙ্গারু',
#  'অন্তরঙ্গতা',
#  'হাভাতে-চিকেন',
#  'হজ',
#  'কেড়ে',
#  'স্বাদ',
#  'মাল্টিমিডিয়া',
#  'বৃদ্ধাঙ্গুলি',
#  'খুজে',
#  'পড়ালে',
#  'ভাঙে',
#  'বালিকা-এর',
#  'মুক্তিযুদ্ধের',
#  'ধারনাটি',
#  'বাড়িয়ে-চাড়িয়ে',
#  'ফোনের',
#  'লেনটি',
#  'স্বরাষ্ট্রমন্ত্রী',
#  'একদিনের',
#  'ঢুকিয়েছি',
#  'বিস্ময়কর',
#  'সংকীর্ণ',
#  'সবদেশে',
#  'স্ত্রী-সন্তানদের',
#  'হালি',
#  'অপ্রাপ্তি',
#  'ওঠেনি',
#  'ভোটারবিহীন',
#  'চরিত্রের',
#  'হুইলচেয়ার',
#  'নারায়নগঞ্জের',
#  'শিক্ষাব্যবস্থাকে',
#  'থাকবেন—নিজের',
#  'সেসব',
#  'উল্টোটাও',
#  'গল্প০১.ঘুম',
#  'সমস্যায়',
#  'পৌছাতে',
#  'বিপদের',
#  'ভন্ড',
#  '০৫.আমরা',
#  'মানুষেরাও',
#  'রাস্তা',
#  'উদ্দেশ্যে',
#  'যাবার',
#  'দুশ্চিন্তায়',
#  'স্কলারশিপ',
#  '…হ্যাঁ',
#  'কালচারাল',
#  'লোভীক্ষক',
#  'টুঁ',
# ...

# %%
#Max length of the language
lenght_list=[]
for l in lines:
    lenght_list.append(len(l.split(' ')))
max_length = np.max(lenght_list)
max_length

target_words = sorted(list(all_words))

# %%
#storing the vocab size for encoder and decoder
num_of_encoder_tokens = len(all_words)
num_of_decoder_tokens = len(all_words)
num_of_decoder_tokens += 1

# %%
# dictionary to index each english character - key is index and value is english character
word_index_to_char_dict = {}
# dictionary to get english character given its index - key is english character and value is index
word_char_to_index_dict = {}
for key, value in enumerate(target_words):
    word_index_to_char_dict[key] = value
    word_char_to_index_dict[value] = key

word_char_to_index_dict[value] = key

# %%
# Splitting our data into train and tes part
from sklearn.model_selection import train_test_split
X, y = lines, lines
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

main_Xtrain = []
main_ytrain = []
for line in X_train:
  message = ""
  for w in line.split():
    message += w + " " 
    main_Xtrain.append(message)
    m = ""
    for word in reversed(line.split()):
      if(word == w):
        main_ytrain.append(m)
        continue
      else:
        m = " " + word + m


main_Xtest = []
main_ytest = []
for line in X_test:
  message = ""
  for w in line.split():
    message += w + " "
    main_Xtest.append(message)
    m = ""
    for word in reversed(line.split()):
      if(word == w):
        main_ytest.append(m)
        continue
      else:
        m = " " + word + m

print(main_ytest[40])
main_Xtest[40]
# Out:
#  কিন্তু বখশিশ শব্দটায় তাচ্ছিল্য কিংবা অবমাননার ছাপ রয়েছে _END
# 'START_ কিন্তু বখশিশ শব্দটায় তাচ্ছিল্য কিংবা অবমাননার ছাপ রয়েছে '

# %%
main_Xtest[:5], main_ytest[:5]
# Out:
# (['START_ ',
#   'START_ কিছু ',
#   'START_ কিছু কিছু ',
#   'START_ কিছু কিছু বইয়ের ',
#   'START_ কিছু কিছু বইয়ের পেছনের '],
#  [' কিছু কিছু বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#   ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#   ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#   ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#   ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END'])

# %%
main_ytest[:5]
# Out:
# [' কিছু কিছু বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END']

# %%
main_ytest[0:5]
# Out:
# [' কিছু কিছু বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END',
#  ' বইয়ের পেছনের কাহিনী অবিশ্বাস্য _END']

# %%
#we will not train on whole data at time instead we will train on batch so as to reduce computation and increase learning and performace of model
def generate_batch(X = main_Xtrain, y = main_ytrain, batch_size = 128):
    while True:
        for j in range(0, len(X), batch_size):
            
            #encoder input
            encoder_input_data = np.zeros((batch_size, max_length),dtype='float32')
            #decoder input
            decoder_input_data = np.zeros((batch_size, max_length),dtype='float32')

        
            
            #target 
            decoder_target_data = np.zeros((batch_size, max_length, num_of_decoder_tokens),dtype='float32')
            

            

            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
               # print("Data List: " + X[j])
                for t, word in enumerate(input_text.split()):
                    #print("In the Batch Function\n")
                    #print(word)
                    #print(word_char_to_index_dict[word])
                    encoder_input_data[i, t] = word_char_to_index_dict[word] # encoder input seq
                    
                for t, word in enumerate(target_text.split()):
                    if t<len(target_text.split())-1:
                        decoder_input_data[i, t] = word_char_to_index_dict[word] # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        # Offset by one timestep since it is one time stamp ahead
                        decoder_target_data[i, t - 1, word_char_to_index_dict[word]] = 1

            #encoder_input_data = np.reshape(encoder_input_data, (None, 1, encoder_input_data.shape[1]))
            #decoder_input_data = np.reshape(decoder_input_data, (decoder_input_data.shape[0], 1, decoder_input_data.shape[1]))
              
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %%
latent_dim = 256   #The number of cells to create in the encoder and decoder models, e.g. 128 or 256.
# Encoder
encoder_inputs = Input(shape=(None,))
enc_emb =  Embedding(num_of_encoder_tokens, latent_dim, mask_zero = True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
#encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
import tensorflow as tf

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, ))
dec_emb_layer = Embedding(num_of_decoder_tokens, latent_dim, mask_zero = True)
dec_emb = dec_emb_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

#hidden_with_time_axis = tf.expand_dims(latent_dim, -1)                
#score = (Dense(encoder_outputs))

#attention_weights = softmax(score, axis=1)                     
#context_vector = attention_weights * encoder_output
#context_vector = tf.reduce_sum(context_vector, axis=1)
#x = Concatenate([tf.expand_dims(context_vector, 1),dec_emb], axis=-1)
#x = Concatenate([tf.expand_dims(encoder_outputs, 1),dec_emb])
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)      #lesson: https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

decoder_dense = Dense(num_of_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)
#decoder_outputs = Reshape(decoder_outputs, (-1, decoder_outputs.shape[2]))


model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
#Compile Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#X_train = Reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
#X_test = Reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
#X_train_reshape = X_train.reshape(X_train, 1,1)
#X_test_reshape = X_test.reshape(X_test, 1,1)
train_samples = len(main_Xtrain)
val_samples = len(main_Xtest)
batch_size =40
epochs = 250

# %%
  history=model.fit_generator(generator = generate_batch(main_Xtrain, main_ytrain, batch_size = batch_size),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs,
                    validation_data = generate_batch(main_Xtest, main_ytest,    batch_size = batch_size),
                    validation_steps = val_samples//batch_size )
# Out:
# Epoch 1/250
# 2534/2534 [==============================] - 1418s 559ms/step - loss: 7.0873 - acc: 0.1138 - val_loss: 6.8284 - val_acc: 0.1267
# Epoch 2/250
# 2105/2534 [=======================>......] - ETA: 3:22 - loss: 6.0656 - acc: 0.1309

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32e4fedfbdab> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['acc'])
#       4 plt.plot(history.history['val_acc'])
#       5 plt.title('model accuracy')
#
# NameError: name 'history' is not defined

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save_weights('./weights.h5')

# %%
# Inference model
#storing encoder input and internal states so as to give to decoder part
encoder_model = Model(encoder_inputs, encoder_states)
#specifying hidden and cell state for decoder part as vector process it will get output predicted and again we add to decoder states
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
dec_emb2= dec_emb_layer(decoder_inputs) # Get the embeddings of the decoder sequence
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)
 # A dense softmax layer to generate prob dist. over the target vocabulary
# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %%
def decode_sequence(input_seq, last_word):
    last_word = last_word[:-1]
    last_word = last_word.split()[-1]
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    #print(states_value)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    #target_seq = np.zeros(120, dtype='float32')
    # Populate the first character of target sequence with the start character.
    #target_seq[0, 0] = word_char_to_index_dict['START_']#last_word]
    target_seq[0,0] = word_char_to_index_dict[last_word]
    #mine target_seq[0] = word_char_to_index_dict['START_']#last_word]
# Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
# Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = word_index_to_char_dict[sampled_token_index]
        decoded_sentence += ' '+sampled_char
        #input_sentence += ' '+sampled_char
        #print("sentence with new word: \n")
        #print(decoded_sentence)
# Exit condition: either hit max length                        
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 250):
            stop_condition = True
# Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index
        #target_seq[0] = sampled_token_index
        #input_to_test = np.zeros(120, dtype='float32')
        #for t, word in enumerate(input_sentence.split(' ')):
         # input_seq[t] = word_char_to_index_dict[word]
        #              input_seq[0] = sampled_token_index
# Update states
        states_value = [h, c]
        # this should be changed
    print("Predicted suggeston as per data: "+ decoded_sentence)
    return decoded_sentence

# %%
# generate target given source sequence
def predict_sequence(input_seq):
 # encode
 state = encoder_model.predict(input_seq)
 # start of sequence input
 target_seq = np.zeros((0,0))
 # collect predictions
 output = list()
 sentence= ''
 stop_condition = False
 while not stop_condition:
  # predict next char
  output_tokens, h, c = decoder_model.predict([input_seq] + state)
  # store prediction
  output.append(output_tokens[0,0,:])
  sampled_token_index = np.argmax(output_tokens[0, 0, :])
  sampled_char = word_index_to_char_dict[sampled_token_index]
  sentence += ' '+sampled_char  
  if (sampled_char == '_END' or len(output) > 50):
    stop_condition = True
  # update state
  state = [h, c]
  # update target sequence
  target_seq = output_tokens
  
 print('SENTENCE is:' + sentence)
 return np.array(output)

# %%
train_gen = generate_batch(main_Xtest, main_ytest, batch_size = 3)
value = len(main_Xtest)
for k in range(value):
  (input_seq, actual_output), _ = next(train_gen)
  print('Input English sentence as per data:', main_Xtest[k])
  decoded_sentence = decode_sequence(input_seq, main_Xtest[k])
  print('Actual Output as should be:', main_ytest[k])
  print("....................................................................................................................")

# %%
def get_sequence_toTest(sentence):

  input_to_test = np.zeros(120, dtype='float32')

  for t, word in enumerate(sentence.split(' ')):
    input_to_test[t] = word_char_to_index_dict[word]

  
  return input_to_test

# %%
sentence ='START_ ' 
input_sequence = get_sequence_toTest(sentence);
decoded_sentence = decode_sequence(input_sequence, sentence)
decoded_sentence
